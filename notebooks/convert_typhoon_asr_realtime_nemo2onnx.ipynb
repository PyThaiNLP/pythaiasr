# %%
# !git clone https://github.com/moabdelmoez/fastconformer-quran-onnx.git
# Out:
# Cloning into 'fastconformer-quran-onnx'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 14 (delta 5), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (14/14), 4.83 KiB | 4.83 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
cd fastconformer-quran-onnx
# Out:
# /content/fastconformer-quran-onnx

# %%
# !wget https://huggingface.co/typhoon-ai/typhoon-asr-realtime/resolve/main/typhoon-asr-realtime.nemo
# Out:
# --2026-09-11 17:57:35--  https://huggingface.co/typhoon-ai/typhoon-asr-realtime/resolve/main/typhoon-asr-realtime.nemo
# Resolving huggingface.co (huggingface.co)... 18.172.21.113, 18.172.21.21, 18.172.21.18, ...
# Connecting to huggingface.co (huggingface.co)|18.172.21.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !pip install -qr requirements.txt
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 48.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.6/23.6 MB 39.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 14.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 903.9/903.9 kB 48.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 811.0/811.0 kB 46.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 52.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.8/242.8 kB 17.7 MB/s eta 0:00:00
# ...

# %%
# !python scripts/export_to_onnx.py --model-id typhoon-asr-realtime.nemo --output-dir onnx --check-onnx
# Out:
# Loading typhoon-asr-realtime.nemo ...
# OneLogger: Setting error_handling_strategy to DISABLE_QUIETLY_AND_REPORT_METRIC_ERROR for rank (rank=0) with OneLogger disabled. To override: explicitly set error_handling_strategy parameter.
# No exporters were provided. This means that no telemetry data will be collected.
# [NeMo I 2026-09-11 17:59:55 mixins:194] Tokenizer SentencePieceTokenizer initialized with 2048 tokens
# [NeMo W 2026-09-11 17:59:57 modelPT:175] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: /data/workspace/warit/nemo-asr/stt_th_conformer_transducer_large/prepare_data/typhoon_cleanser/20250814/Split_gg/train_data_typhoon_asr_realtime.jsonl
#     sample_rate: 16000
#     batch_size: 8
#     shuffle: true
#     num_workers: 8
#     pin_memory: true
#     use_start_end_token: false
#     trim_silence: false
# ...

# %%
# !zip -qr onnx.zip onnx

# %%
# !pip install -q pythaiasr
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.6/23.6 MB 38.1 MB/s eta 0:00:00

# %%
# !wget https://github.com/PyThaiNLP/pythaiasr/raw/refs/heads/main/tests/test-diarize.wav
# Out:
# --2026-09-14 16:21:35--  https://github.com/PyThaiNLP/pythaiasr/raw/refs/heads/main/tests/test-diarize.wav
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/PyThaiNLP/pythaiasr/refs/heads/main/tests/test-diarize.wav [following]
# --2026-09-14 16:21:36--  https://raw.githubusercontent.com/PyThaiNLP/pythaiasr/refs/heads/main/tests/test-diarize.wav
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 413298 (404K) [audio/wav]
# Saving to: ‘test-diarize.wav’
#
# test-diarize.wav    100%[===================>] 403.61K  --.-KB/s    in 0.04s
#
# 2026-09-14 16:21:36 (9.59 MB/s) - ‘test-diarize.wav’ saved [413298/413298]

# %%
from pythaiasr import asr,asr_diarize,diarize
import IPython

# %%
file="test-diarize.wav"
IPython.display.Audio(file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# With timestamps (returns dictionary with 'text', 'chunks', and 'timestamps')
result = asr(file, return_timestamps=True)
print(result["text"])
for chunk in result["chunks"]:
    print(f"[{chunk['start']:.2f}s -> {chunk['end']:.2f}s] {chunk['text']}")
# Out:
# สวัสดีชาวโลกทุกท่าน แล้วระบบนี้ทํางานอย่างไร ใช้ปัญญาประดิษฐ์ในการทดสอบ ใช้งานได้ดีทีเดียว
# [0.24s -> 1.52s] สวัสดีชาวโลกทุกท่าน
# [2.00s -> 2.08s] แล้ว
# [2.48s -> 3.28s] ระบบนี้ทํางาน
# [3.68s -> 3.76s] อย่างไร
# [4.88s -> 6.24s] ใช้ปัญญาประดิษฐ์ในการทดสอบ
# [6.72s -> 7.92s] ใช้งานได้ดีทีเดียว

# %%
# Attributed transcription per speaker
turns = asr_diarize(file, asr_model="typhoon_asr")
for turn in turns:
    print(f"[{turn['start']:.2f}s - {turn['end']:.2f}s] {turn['speaker']}: {turn['text']}")
# Out:
# [0.20s - 1.83s] SPEAKER_02: สวัสดีชาวโลกทุกท่าน
# [1.97s - 4.25s] SPEAKER_01: แล้วระบบนี้ทํางานอย่างไร
# [4.83s - 6.47s] SPEAKER_02: ใช้ปัญญาประดิษฐ์ในการทดสอบ
# [6.78s - 8.31s] SPEAKER_01: ใช้งานได้ดีทีเดียว

# %%
# Identify who spoke when
segments = diarize(file)
for seg in segments:
    print(f"[{seg['start']:.2f}s - {seg['end']:.2f}s] {seg['speaker']}")
# Out:
# [0.20s - 1.83s] SPEAKER_02
# [1.97s - 4.25s] SPEAKER_01
# [4.83s - 6.47s] SPEAKER_02
# [6.78s - 8.31s] SPEAKER_01
